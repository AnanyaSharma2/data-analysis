# %%
import pandas as pd

# %% [markdown]
# ## **Add CSV file using Pandas**

# %%
data = pd.read_csv(r"/Netflix Dataset.csv")

# %% [markdown]
# ### **Printing the Data Frame**

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## **Getting some basic information about the dataset**

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Date_N        7777 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 1.0+ MB

# %% [markdown]
# ## **Data Cleaning by finding and removing the duplicates.**

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# ## **Deleting the duplicates using drop_duplicates(inplace=True) Function**

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# **Finding the Null Values in All Columns**

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### Importing a Sea Born Library to create a **Heat** Map **bold text**

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **Creating a new Columns Date_N containing the release date column in data type Date time**

# %%
data["Date_N"]=pd.to_datetime(data['Release_Date'])

# %% [markdown]
# ## **Printing the Top Five Rows of Data Frame**

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # **Ploting a Bar Graph in which higest number of TV Shows and Movies were realesed**

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## **Grouping the Categories **

# %%
data.groupby('Category').count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      5214  4951     5147          5377    5372
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description  Date_N
# Category
# Movie         5377  5377         5377    5377
# TV Show       2410  2410         2410    2400

# %% [markdown]
# # **Ploting the Category using countplot function**

# %%
sns.countplot(data['Category'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## **Counting the no. of Tv Shows and movies released by the Director**

# %%
data['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: Director, Length: 4050, dtype: int64

# %% [markdown]
# ### **Top 5 Director who gives the highest no of Tv shows and Movies to Netflix**

# %%
data['Director'].value_counts().head(5)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Name: Director, dtype: int64

# %% [markdown]
# ### **Creating the new data Frame using dropna()**

# %%
data_new=data.dropna()

# %% [markdown]
# ### **Printing the top 5 Rows of new data Frame**

# %%
data_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %% [markdown]
# ***Listing the names of movies and Shows Casted by Tom Cruise ***

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N
# 3860  Through chance, human action, past history and... 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %% [markdown]
# ## **Number of unique values in rating column**

# %%
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# ### **Printing the unique rating values**

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **Rating Graph**

# %%
sns.countplot(data['Rating'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %% [markdown]
# **Getting the unique duration values in the dataframe**

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %% [markdown]
# **Finding the minimum and maximum duration values**

# %%
data.Duration.max()
# Out:
# '99 min'

# %%
data.Duration.min()
# Out:
# '1 Season'

# %% [markdown]
# ## **Duration Graph**

# %%
sns.countplot(data['Duration'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Duration', ylabel='count'>

# %% [markdown]
# **Getting information regarding shows released country wise**

# %%
data_tvshow=data[data['Category']=='TV Show']

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# **Finding the leading two countries in Tv Shows**

# %%
data_tvshow.Country.value_counts().head(2)
# Out:
# United States     705
# United Kingdom    204
# Name: Country, dtype: int64

# %% [markdown]
# ## **Sorting the data frame by Date_N column**

# %%
data.sort_values(by='Date_N',ascending=False)
# Out:
#      Show_Id Category                         Title  \
# 1673   s1674    Movie                   Death of Me
# 5060   s5060    Movie                  Radium Girls
# 205     s206    Movie               A Monster Calls
# 1832   s1833    Movie                    Double Dad
# 4710   s4711    Movie              Outside the Wire
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                               Director  \
# 1673               Darren Lynn Bousman
# 5060  Lydia Dean Pilcher, Ginny Mohler
# 205                        J.A. Bayona
# 1832                      Cris D'Amato
# 4710                   Mikael Håfström
# ...                                ...
# 3374                               NaN
# ...

# %% [markdown]
# ## **Finding the instances where **
# # **Category= Movie and Type=Horror Movies**
# ## **Category =TV SHow and Type= TV Comedies**

# %%
s=(data['Category']=='TV Show') & (data['Type']== 'TV Comedies')

# %%
g=(data['Category']=='Movie') & (data['Type']== 'Horror Movies')

# %% [markdown]
# # **Printing **
# ## **Category =TV SHow and Type= TV Comedies**

# %%
data[s]
# Out:
#      Show_Id Category                                     Title Director  \
# 29       s30  TV Show                                  #blackAF      NaN
# 306     s307  TV Show                     Adam Ruins Everything      NaN
# 404     s405  TV Show                 All About the Washingtons      NaN
# 583     s584  TV Show                      Arrested Development      NaN
# 603     s604  TV Show           Astronomy Club: The Sketch Show      NaN
# ...      ...      ...                                       ...      ...
# 7320   s7319  TV Show                 Unbreakable Kimmy Schmidt      NaN
# 7452   s7451  TV Show                            W/ Bob & David      NaN
# 7544   s7543  TV Show                   Wet Hot American Summer      NaN
# 7545   s7544  TV Show  Wet Hot American Summer: Ten Years Later      NaN
# 7737   s7736  TV Show                            Young & Hungry      NaN
#
#                                                    Cast        Country  \
# ...

# %% [markdown]
# # **Printing **
# # **Category= Movie and Type=Horror Movies**

# %%
data[g]
# Out:
#      Show_Id Category                         Title  \
# 261     s262    Movie                        A.M.I.
# 417     s418    Movie  All the Boys Love Mandy Lane
# 1551   s1552    Movie                Cult of Chucky
# 1654   s1655    Movie                       Deadcon
# 1671   s1672    Movie                   Death House
# 1673   s1674    Movie                   Death of Me
# 1811   s1812    Movie   Don't Be Afraid of the Dark
# 1976   s1977    Movie                           Eli
# 2104   s2105    Movie                  Family Blood
# 2165   s2166    Movie           Final Destination 3
# 2286   s2287    Movie               Friday the 13th
# 2394   s2395    Movie                   Ghost House
# 2405   s2406    Movie                 Ghosts of War
# 2422   s2423    Movie       Girl on the Third Floor
# 2704   s2705    Movie                    Here Alone
# 2833   s2834    Movie            House of the Witch
# 3456   s3457    Movie                        Kristy
# ...
